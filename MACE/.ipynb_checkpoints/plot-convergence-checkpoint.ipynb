# %%
import os
import library.convergence as con

for root, dirs, files in os.walk("/Users/cibran/Desktop/ss_0.875"):
    if "GdCeO2.traj" in files:
        con.analyze_convergence_and_diffusion(md_path=root)
